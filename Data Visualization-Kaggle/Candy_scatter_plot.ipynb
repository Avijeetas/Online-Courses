# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# !ls
# Out:
# candy.csv  spotify.csv	Spotify.ipynb  Untitled.ipynb

# %%
candy_data=pd.read_csv("candy.csv",index_col='id')
candy_data.head(5)
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
df=candy_data
lst=[]
lst=df['competitorname'].unique().values.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-73bb41a1fddd> in <module>
#       1 df=candy_data
#       2 lst=[]
# ----> 3 lst=df['competitorname'].unique().values.tolist()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
df.iloc[df['winpercent'].argmax()]
# Out:
# /home/avijeet/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# competitorname      Reese's Peanut Butter cup
# chocolate                                 Yes
# fruity                                     No
# caramel                                    No
# peanutyalmondy                            Yes
# nougat                                     No
# crispedricewafer                           No
# hard                                       No
# bar                                        No
# pluribus                                   No
# sugarpercent                             0.72
# pricepercent                            0.651
# ...

# %%
df['winpercent'].values.max()
# Out:
# 84.18029

# %%
df.head(5)
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['sugarpercent'], y=df['winpercent'])

plt.title('Relationship between sugarpercent and winpercent')
# Out:
# Text(0.5, 1.0, 'Relationship between sugarpercent and winpercent')

# %%
sns.regplot(x=df['sugarpercent'], y=df['winpercent'])
plt.title('Relationship between sugarpercent and winpercent with regression line')
# Out:
# Text(0.5, 1.0, 'Relationship between sugarpercent and winpercent with regression line')

# %%
sns.scatterplot(x=df['sugarpercent'], y=df['winpercent'],hue=df['chocolate'])
plt.title('Relationship between sugarpercent and winpercent in terms of chocolate')
# Out:
# Text(0.5, 1.0, 'Relationship between sugarpercent and winpercent with regression line')

# %%
sns.lmplot(x='sugarpercent',y='winpercent',hue='chocolate',data=df)

# %%
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['winpercent'], y=df['pricepercent'],hue=df['peanutyalmondy'])

plt.title('Relationship between sugarpercent and winpercent on the basis of peanutyalmondy')
# Out:
# Text(0.5, 1.0, 'Relationship between sugarpercent and winpercent on the basis of peanutyalmondy')

# %%
sns.regplot(x=df['winpercent'], y=df['pricepercent'])
plt.title('Relationship between sugarpercent and winpercent with regression line')
# Out:
# Text(0.5, 1.0, 'Relationship between sugarpercent and winpercent with regression line')

# %%
sns.swarmplot(x=candy_data['peanutyalmondy'], y=candy_data['winpercent'])
